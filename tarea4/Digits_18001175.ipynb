# %% [markdown]
# <a href="https://colab.research.google.com/github/jBarrios26/SP1_ML/blob/main/tarea4/Digits_18001175.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports

# %%
import tensorflow as tf
import os
import json
import numpy as np
from matplotlib import pyplot as plt

print("TersorFlow version", tf.__version__ )
# Out:
# TersorFlow version 2.4.1

# %% [markdown]
# ## Funciones por instructor de google labs
#   Sirven para dibujar los números
#
#   Créditos: Martin Gorner
#   URL: https://colab.research.google.com/github/GoogleCloudPlatform/tensorflow-without-a-phd/blob/master/tensorflow-mnist-tutorial/keras_01_mnist.ipynb#scrollTo=hleIN5-pcr0N

# %%
import PIL.Image, PIL.ImageFont, PIL.ImageDraw
import IPython.display as display
# Matplotlib config
plt.ioff()
plt.rc('image', cmap='gray_r')
plt.rc('grid', linewidth=1)
plt.rc('xtick', top=False, bottom=False, labelsize='large')
plt.rc('ytick', left=False, right=False, labelsize='large')
plt.rc('axes', facecolor='F8F8F8', titlesize="large", edgecolor='white')
plt.rc('text', color='a8151a')
plt.rc('figure', facecolor='F0F0F0', figsize=(16,9))
# Matplotlib fonts
MATPLOTLIB_FONT_DIR = os.path.join(os.path.dirname(plt.__file__), "mpl-data/fonts/ttf")

# create digits from local fonts for testing
def create_digits_from_local_fonts(n):
  font_labels = []
  img = PIL.Image.new('LA', (28*n, 28), color = (0,255)) # format 'LA': black in channel 0, alpha in channel 1
  font1 = PIL.ImageFont.truetype(os.path.join(MATPLOTLIB_FONT_DIR, 'DejaVuSansMono-Oblique.ttf'), 25)
  font2 = PIL.ImageFont.truetype(os.path.join(MATPLOTLIB_FONT_DIR, 'STIXGeneral.ttf'), 25)
  d = PIL.ImageDraw.Draw(img)
  for i in range(n):
    font_labels.append(i%10)
    d.text((7+i*28,0 if i<10 else -4), str(i%10), fill=(255,255), font=font1 if i<10 else font2)
  font_digits = np.array(img.getdata(), np.float32)[:,0] / 255.0 # black in channel 0, alpha in channel 1 (discarded)
  font_digits = np.reshape(np.stack(np.split(np.reshape(font_digits, [28, 28*n]), n, axis=1), axis=0), [n, 28*28])
  return font_digits, font_labels

# utility to display a row of digits with their predictions
def display_digits(digits, predictions, labels, title, n):
  fig = plt.figure(figsize=(13,3))
  digits = np.reshape(digits, [n, 28, 28])
  digits = np.swapaxes(digits, 0, 1)
  digits = np.reshape(digits, [28, 28*n])
  plt.yticks([])
  plt.xticks([28*x+14 for x in range(n)], predictions)
  plt.grid(b=None)
  for i,t in enumerate(plt.gca().xaxis.get_ticklabels()):
    if predictions[i] != labels[i]: t.set_color('red') # bad predictions in red
  plt.imshow(digits)
  plt.grid(None)
  plt.title(title)
  display.display(fig)

# %% [markdown]
# # Constantes necesarias

# %%
BATCH_SIZE = 128
EPOCHS = 10

training_images_file   = 'gs://mnist-public/train-images-idx3-ubyte'
training_labels_file   = 'gs://mnist-public/train-labels-idx1-ubyte'
validation_images_file = 'gs://mnist-public/t10k-images-idx3-ubyte'
validation_labels_file = 'gs://mnist-public/t10k-labels-idx1-ubyte'

# %% [markdown]
# # Funciones para cargar el dataset de imagenes.

# %%
def leer_imagen(tf_bytestring):
  imagen = tf.io.decode_raw(tf_bytestring, tf.uint8)
  imagen = tf.cast(imagen, tf.float32)/256.0
  imagen = tf.reshape(imagen, [28*28])
  return imagen

def leer_etiquetas(tf_bytestring):
  tag = tf.io.decode_raw(tf_bytestring, tf.uint8)
  tag = tf.reshape(tag, [])
  tag = tf.one_hot(tag, 10)
  return tag

def cargar_dataset(image_filename, label_filename):
  image_dataset = tf.data.FixedLengthRecordDataset(image_filename, 28*28, header_bytes=16) #Cargar el dataset de las imagenes
  image_dataset = image_dataset.map(leer_imagen, num_parallel_calls = 16) # Se lee cada imagen
  label_dataset = tf.data.FixedLengthRecordDataset(label_filename, 1, header_bytes=8) # Cargar el dataset de las etiquetas
  label_dataset = label_dataset.map(leer_etiquetas, num_parallel_calls = 16) # Se leen las etiquetas
  dataset = tf.data.Dataset.zip((image_dataset, label_dataset)) # Se junta cada imagen con su etiqueta. (imagen, label)
  return dataset

def cargar_set_entrenamiento(image_filename, label_filename):
  dataset = cargar_dataset(image_filename, label_filename)
  dataset = dataset.cache() # Guarda el batch de imagenes en la RAM 
  dataset = dataset.shuffle(5000, reshuffle_each_iteration = True) # Mezcla las imagenen en el batch
  dataset = dataset.repeat() # Encicla el dataset
  dataset = dataset.batch(BATCH_SIZE) # Crea grupos de imagenes de tamaño 128. 
  dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE) # Empieza a cargar el siguiente batch mientras el actual sigue procesandose. 
  return dataset

def cargar_set_validacion(image_filename, label_filename):
  dataset = cargar_dataset(image_filename, label_filename)
  dataset = dataset.cache() # Guarda el batch de imagenes en la RAM 
  dataset = dataset.batch(10000, drop_remainder = True) # Solo un batch del tamaño completo del dataset
  dataset = dataset.repeat() # Encicla el dataset
  return dataset

set_entrenamiento = cargar_set_entrenamiento(training_images_file, training_labels_file)
set_validacion = cargar_set_validacion(validation_images_file, validation_labels_file)

# %% [markdown]
# # Crear el modelo: Utilizando como optimizador SGD

# %%
model = tf.keras.Sequential([
                             tf.keras.layers.Input(shape=(28*28, )),
                             tf.keras.layers.Dense(10, activation='softmax')
        ])

# %%
model.compile(optimizer='sgd',
              loss= 'categorical_crossentropy',
              metrics = 'accuracy'
              )

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 10)                7850
# =================================================================
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #Entrenar el modelo

# %%
steps_per_epoch = 60000//BATCH_SIZE 
history = model.fit(set_entrenamiento, steps_per_epoch=steps_per_epoch, epochs=EPOCHS,
          validation_data=set_validacion, validation_steps=1)
# Out:
# Epoch 1/100
# 468/468 [==============================] - 7s 10ms/step - loss: 1.6275 - accuracy: 0.5628 - val_loss: 0.8039 - val_accuracy: 0.8400
# Epoch 2/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.7618 - accuracy: 0.8361 - val_loss: 0.6053 - val_accuracy: 0.8659
# Epoch 3/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.6061 - accuracy: 0.8573 - val_loss: 0.5245 - val_accuracy: 0.8768
# Epoch 4/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.5337 - accuracy: 0.8690 - val_loss: 0.4793 - val_accuracy: 0.8818
# Epoch 5/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.4925 - accuracy: 0.8754 - val_loss: 0.4496 - val_accuracy: 0.8856
# Epoch 6/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.4623 - accuracy: 0.8811 - val_loss: 0.4283 - val_accuracy: 0.8895
# Epoch 7/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.4414 - accuracy: 0.8856 - val_loss: 0.4122 - val_accuracy: 0.8920
# Epoch 8/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0
100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2935 - accuracy: 0.9197 - val_loss: 0.2896 - val_accuracy: 0.9194
# Epoch 71/100
# 468/468 [==============================] - 2s 4ms/step - loss: 0.2849 - accuracy: 0.9223 - val_loss: 0.2894 - val_accuracy: 0.9193
# Epoch 72/100
# 468/468 [==============================] - 2s 4ms/step - loss: 0.2843 - accuracy: 0.9214 - val_loss: 0.2888 - val_accuracy: 0.9194
# Epoch 73/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2809 - accuracy: 0.9223 - val_loss: 0.2887 - val_accuracy: 0.9199
# Epoch 74/100
# 468/468 [==============================] - 2s 4ms/step - loss: 0.2842 - accuracy: 0.9224 - val_loss: 0.2882 - val_accuracy: 0.9200
# Epoch 75/100
# 468/468 [==============================] - 2s 4ms/step - loss: 0.2772 - accuracy: 0.9232 - val_loss: 0.2881 - val_accuracy: 0.9202
# Epoch 76/100
# 468/468 [==============================] - 2s 4ms/step - loss: 0.2825 - accuracy: 0.9224 - val_loss: 0.2877 - val_accuracy: 0.9201
# Epoch 77/100
# 468/468 [==============================] - 2s 4ms/step - loss: 0.2812 - accuracy: 0.9230 - val_loss: 0.2873 - val_accuracy: 0.9203
# Epoch 78/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2805 - accuracy: 0.9222 - val_loss: 0.2873 - val_accuracy: 0.9202
# Epoch 79/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2811 - accuracy: 0.9223 - val_loss: 0.2871 - val_accuracy: 0.9201
# Epoch 80/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2789 - accuracy: 0.9221 - val_loss: 0.2868 - val_accuracy: 0.9203
# Epoch 81/100
# 468/468 [==============================] - 2s 4ms/step - loss: 0.2830 - accuracy: 0.9221 - val_loss: 0.2864 - val_accuracy: 0.9201
# Epoch 82/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2839 - accuracy: 0.9220 - val_loss: 0.2860 - val_accuracy: 0.9204
# Epoch 83/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2826 - accuracy: 0.9224 - val_loss: 0.2858 - val_accuracy: 0.9202
# Epoch 84/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2807 - accuracy: 0.9227 - val_loss: 0.2856 - val_accuracy: 0.9206
# Epoch 85/100
# 468/468 [==============================] - 2s 4ms/step - loss: 0.2842 - accuracy: 0.9215 - val_loss: 0.2854 - val_accuracy: 0.9206
# Epoch 86/100
# 468/468 [==============================] - 2s 4ms/step - loss: 0.2776 - accuracy: 0.9237 - val_loss: 0.2852 - val_accuracy: 0.9202
# Epoch 87/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2808 - accuracy: 0.9233 - val_loss: 0.2848 - val_accuracy: 0.9207
# Epoch 88/100
# 468/468 [==============================] - 1s 3ms/step - loss: 0.2786 - accuracy: 0.9230 - val_loss: 0.2846 - val_accuracy: 0.9203
# Epoch 89/100
# 468/468 [==============================] - 2s 4ms/step - loss: 0.2733 - accuracy: 0.9241 - val_loss: 0.2845 - val_accuracy: 0.9203
# Epoch 90/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2800 - accuracy: 0.9227 - val_loss: 0.2842 - val_accuracy: 0.9203
# Epoch 91/100
# 468/468 [==============================] - 2s 4ms/step - loss: 0.2793 - accuracy: 0.9220 - val_loss: 0.2839 - val_accuracy: 0.9201
# Epoch 92/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2770 - accuracy: 0.9233 - val_loss: 0.2840 - val_accuracy: 0.9209
# Epoch 93/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2811 - accuracy: 0.9214 - val_loss: 0.2838 - val_accuracy: 0.9205
# Epoch 94/100
# 468/468 [==============================] - 1s 3ms/step - loss: 0.2783 - accuracy: 0.9229 - val_loss: 0.2833 - val_accuracy: 0.9202
# Epoch 95/100
# 468/468 [==============================] - 1s 3ms/step - loss: 0.2800 - accuracy: 0.9216 - val_loss: 0.2831 - val_accuracy: 0.9201
# Epoch 96/100
# 468/468 [==============================] - 1s 3ms/step - loss: 0.2766 - accuracy: 0.9227 - val_loss: 0.2831 - val_accuracy: 0.9205
# Epoch 97/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2760 - accuracy: 0.9237 - val_loss: 0.2830 - val_accuracy: 0.9208
# Epoch 98/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2761 - accuracy: 0.9234 - val_loss: 0.2826 - val_accuracy: 0.9203
# Epoch 99/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2762 - accuracy: 0.9236 - val_loss: 0.2824 - val_accuracy: 0.9203
# Epoch 100/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2814 - accuracy: 0.9230 - val_loss: 0.2822 - val_accuracy: 0.9207

# %% [markdown]
# # Encontrar predicciones

# %%
font_digits, font_labels = create_digits_from_local_fonts(20)
probabilities = model.predict(font_digits, steps=1)
predicted_labels = np.argmax(probabilities, axis=1)
display_digits(font_digits, predicted_labels, font_labels, "predictions from local fonts (bad predictions in red)", 20)

# %% [markdown]
# # Gráficas comparando el accuracy y el loss

# %%
plt.plot(range(EPOCHS), history.history['accuracy'], label='Accuracy')
plt.plot(range(EPOCHS), history.history['val_accuracy'], label='Validation Accuracy')
plt.fill_between(range(EPOCHS),
                 history.history['accuracy'],
                 history.history['val_accuracy'],
                 color='salmon',
                 alpha = 0.3)
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# # Crear modelo utilizando como optimizador Adam

# %%
adam_model = tf.keras.Sequential(
    [
     tf.keras.layers.Input(shape=(28*28,)),
     tf.keras.layers.Dense(10, activation='softmax')
    ])

# %%
adam_model.compile(optimizer='adam',
                   loss = 'categorical_crossentropy',
                   metrics='accuracy')

adam_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 10)                7850
# =================================================================
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Entrenar el modelo

# %%
adam_history = adam_model.fit(set_entrenamiento, steps_per_epoch=steps_per_epoch, epochs=EPOCHS,
          validation_data=set_validacion, validation_steps=1)
# Out:
# Epoch 1/100
# 468/468 [==============================] - 2s 4ms/step - loss: 1.0624 - accuracy: 0.7169 - val_loss: 0.3848 - val_accuracy: 0.8999
# Epoch 2/100
# 468/468 [==============================] - 1s 3ms/step - loss: 0.3805 - accuracy: 0.8987 - val_loss: 0.3218 - val_accuracy: 0.9121
# Epoch 3/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.3221 - accuracy: 0.9117 - val_loss: 0.2973 - val_accuracy: 0.9162
# Epoch 4/100
# 468/468 [==============================] - 1s 3ms/step - loss: 0.3014 - accuracy: 0.9168 - val_loss: 0.2855 - val_accuracy: 0.9204
# Epoch 5/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2863 - accuracy: 0.9199 - val_loss: 0.2775 - val_accuracy: 0.9217
# Epoch 6/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2774 - accuracy: 0.9222 - val_loss: 0.2753 - val_accuracy: 0.9221
# Epoch 7/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2694 - accuracy: 0.9250 - val_loss: 0.2690 - val_accuracy: 0.9242
# Epoch 8/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2676 - accuracy: 0.9253 - val_loss: 0.2698 - val_accuracy: 0.9233
# Epoch 9/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2623 - accuracy: 0.9264 - val_loss: 0.2686 - val_accuracy: 0.9254
# Epoch 10/100
# 468/468 [==============================] - 2s 4ms/step - loss: 0.2560 - accuracy: 0.9295 - val_loss: 0.2669 - val_accuracy: 0.9257
# Epoch 11/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2575 - accuracy: 0.9285 - val_loss: 0.2652 - val_accuracy: 0.9255
# Epoch 12/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2519 - accuracy: 0.9301 - val_loss: 0.2639 - val_accuracy: 0.9268
# Epoch 13/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2524 - accuracy: 0.9289 - val_loss: 0.2626 - val_accuracy: 0.9278
# Epoch 14/100
# 468/468 [==============================] - 1s 3ms/step - loss: 0.2486 - accuracy: 0.9315 - val_loss: 0.2649 - val_accuracy: 0.9267
# Epoch 15/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2433 - accuracy: 0.9320 - val_loss: 0.2644 - val_accuracy: 0.9259
# Epoch 16/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2442 - accuracy: 0.9321 - val_loss: 0.2651 - val_accuracy: 0.9251
# Epoch 17/100
# 468/468 [==============================] - 2s 4ms/step - loss: 0.2461 - accuracy: 0.9324 - val_loss: 0.2634 - val_accuracy: 0.9264
# Epoch 18/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2437 - accuracy: 0.9328 - val_loss: 0.2636 - val_accuracy: 0.9267
# Epoch 19/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2422 - accuracy: 0.9334 - val_loss: 0.2633 - val_accuracy: 0.9270
# Epoch 20/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2393 - accuracy: 0.9344 - val_loss: 0.2617 - val_accuracy: 0.9280
# Epoch 21/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.
100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2146 - accuracy: 0.9406 - val_loss: 0.2756 - val_accuracy: 0.9283
# Epoch 83/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2142 - accuracy: 0.9408 - val_loss: 0.2778 - val_accuracy: 0.9273
# Epoch 84/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2138 - accuracy: 0.9415 - val_loss: 0.2788 - val_accuracy: 0.9264
# Epoch 85/100
# 468/468 [==============================] - 2s 4ms/step - loss: 0.2165 - accuracy: 0.9407 - val_loss: 0.2777 - val_accuracy: 0.9267
# Epoch 86/100
# 468/468 [==============================] - 2s 4ms/step - loss: 0.2163 - accuracy: 0.9410 - val_loss: 0.2768 - val_accuracy: 0.9276
# Epoch 87/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2141 - accuracy: 0.9419 - val_loss: 0.2773 - val_accuracy: 0.9287
# Epoch 88/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2126 - accuracy: 0.9417 - val_loss: 0.2776 - val_accuracy: 0.9271
# Epoch 89/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2079 - accuracy: 0.9425 - val_loss: 0.2776 - val_accuracy: 0.9267
# Epoch 90/100
# 468/468 [==============================] - 2s 4ms/step - loss: 0.2120 - accuracy: 0.9413 - val_loss: 0.2784 - val_accuracy: 0.9272
# Epoch 91/100
# 468/468 [==============================] - 2s 4ms/step - loss: 0.2127 - accuracy: 0.9409 - val_loss: 0.2781 - val_accuracy: 0.9275
# Epoch 92/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2146 - accuracy: 0.9403 - val_loss: 0.2772 - val_accuracy: 0.9270
# Epoch 93/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2142 - accuracy: 0.9399 - val_loss: 0.2775 - val_accuracy: 0.9274
# Epoch 94/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2115 - accuracy: 0.9406 - val_loss: 0.2800 - val_accuracy: 0.9269
# Epoch 95/100
# 468/468 [==============================] - 2s 4ms/step - loss: 0.2147 - accuracy: 0.9410 - val_loss: 0.2788 - val_accuracy: 0.9271
# Epoch 96/100
# 468/468 [==============================] - 2s 4ms/step - loss: 0.2175 - accuracy: 0.9406 - val_loss: 0.2790 - val_accuracy: 0.9274
# Epoch 97/100
# 468/468 [==============================] - 2s 4ms/step - loss: 0.2120 - accuracy: 0.9409 - val_loss: 0.2807 - val_accuracy: 0.9269
# Epoch 98/100
# 468/468 [==============================] - 2s 4ms/step - loss: 0.2146 - accuracy: 0.9412 - val_loss: 0.2819 - val_accuracy: 0.9262
# Epoch 99/100
# 468/468 [==============================] - 2s 4ms/step - loss: 0.2155 - accuracy: 0.9404 - val_loss: 0.2800 - val_accuracy: 0.9280
# Epoch 100/100
# 468/468 [==============================] - 2s 3ms/step - loss: 0.2137 - accuracy: 0.9407 - val_loss: 0.2803 - val_accuracy: 0.9271

# %% [markdown]
# # Probando el modelo

# %%
probabilities = adam_model.predict(font_digits, steps=1)
predicted_labels = np.argmax(probabilities, axis=1)
display_digits(font_digits, predicted_labels, font_labels, "predictions from local fonts (bad predictions in red)", 20)

# %% [markdown]
# # Visualizando el accuracy

# %%
plt.plot(range(EPOCHS), adam_history.history['accuracy'], label='Accuracy')
plt.plot(range(EPOCHS), adam_history.history['val_accuracy'], label='Validation Accuracy')
plt.fill_between(range(EPOCHS),
                 adam_history.history['accuracy'],
                 adam_history.history['val_accuracy'],
                 color='salmon',
                 alpha = 0.3)
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# # Comparando ambos modelos

# %%
plt.plot(range(EPOCHS), adam_history.history['accuracy'], label='ADAM: Accuracy')
plt.plot(range(EPOCHS), history.history['accuracy'], label='SGD: Accuracy')
plt.fill_between(range(EPOCHS),
                 adam_history.history['accuracy'],
                 history.history['accuracy'],
                 color='salmon',
                 alpha = 0.3)
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(range(EPOCHS), adam_history.history['val_accuracy'], label='ADAM: Validation Accuracy')
plt.plot(range(EPOCHS), history.history['val_accuracy'], label='SGD: Validation Accuracy')
plt.fill_between(range(EPOCHS),
                 adam_history.history['val_accuracy'],
                 history.history['val_accuracy'],
                 color='salmon',
                 alpha = 0.3)
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# # Tarea 2: Pasos de 6 al 9

# %%
more_layers_model = tf.keras.Sequential(
    [
     tf.keras.layers.Input (shape=(28*28,)),
     tf.keras.layers.Dense (200, activation='sigmoid'),
     tf.keras.layers.Dense (60, activation='sigmoid'),
     tf.keras.layers.Dense (10, activation='softmax')
    ])

more_layers_model.summary ()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 200)               157000
# _________________________________________________________________
# dense_10 (Dense)             (None, 60)                12060
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                610
# =================================================================
# Total params: 169,670
# Trainable params: 169,670
# Non-trainable params: 0
# _________________________________________________________________

# %%
more_layers_model.compile(optimizer='sgd',
              loss= 'categorical_crossentropy',
              metrics = 'accuracy'
              )

# %%
steps_per_epoch = 60000//BATCH_SIZE 
history = more_layers_model.fit(set_entrenamiento, steps_per_epoch=steps_per_epoch, epochs=EPOCHS,
          validation_data=set_validacion, validation_steps=1)
# Out:
# Epoch 1/10
# 468/468 [==============================] - 2s 4ms/step - loss: 2.1746 - accuracy: 0.4669 - val_loss: 2.1272 - val_accuracy: 0.5649
# Epoch 2/10
# 468/468 [==============================] - 2s 4ms/step - loss: 2.0745 - accuracy: 0.5714 - val_loss: 2.0062 - val_accuracy: 0.5934
# Epoch 3/10
# 468/468 [==============================] - 2s 3ms/step - loss: 1.9349 - accuracy: 0.6096 - val_loss: 1.8439 - val_accuracy: 0.6305
# Epoch 4/10
# 468/468 [==============================] - 2s 4ms/step - loss: 1.7589 - accuracy: 0.6433 - val_loss: 1.6541 - val_accuracy: 0.6470
# Epoch 5/10
# 468/468 [==============================] - 2s 4ms/step - loss: 1.5689 - accuracy: 0.6706 - val_loss: 1.4666 - val_accuracy: 0.6882
# Epoch 6/10
# 468/468 [==============================] - 2s 3ms/step - loss: 1.3921 - accuracy: 0.6995 - val_loss: 1.3022 - val_accuracy: 0.7085
# Epoch 7/10
# 468/468 [==============================] - 2s 4ms/step - loss: 1.2416 - accuracy: 0.7226 - val_loss: 1.1649 - val_accuracy: 0.7394
# Epoch 8/10
# 468/468 [==============================] - 2s 3ms/step - loss: 1.1165 - accuracy: 0.7460 - val_loss: 1.0513 - val_accuracy: 0.7630
# Epoch 9/10
# 468/468 [==============================] - 2s 4ms/step - loss: 1.0130 - accuracy: 0.7658 - val_loss: 0.9571 - val_accuracy: 0.7785
# Epoch 10/10
# 468/468 [==============================] - 2s 4ms/step - loss: 0.9267 - accuracy: 0.7848 - val_loss: 0.8788 - val_accuracy: 0.7922

# %%
plt.plot(range(EPOCHS), history.history['accuracy'], label='Accuracy')
plt.plot(range(EPOCHS), history.history['val_accuracy'], label='Validation Accuracy')
plt.fill_between(range(EPOCHS),
                 history.history['accuracy'],
                 history.history['val_accuracy'],
                 color='salmon',
                 alpha = 0.3)
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Utilizando RELU y ADAM

# %%
more_layers_model = tf.keras.Sequential(
    [
     tf.keras.layers.Input (shape=(28*28,)),
     tf.keras.layers.Dense (200, activation='relu'),
     tf.keras.layers.Dense (60, activation='relu'),
     tf.keras.layers.Dense (10, activation='softmax')
    ])

more_layers_model.summary ()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 200)               157000
# _________________________________________________________________
# dense_13 (Dense)             (None, 60)                12060
# _________________________________________________________________
# dense_14 (Dense)             (None, 10)                610
# =================================================================
# Total params: 169,670
# Trainable params: 169,670
# Non-trainable params: 0
# _________________________________________________________________

# %%
more_layers_model.compile(optimizer='adam',
              loss= 'categorical_crossentropy',
              metrics = 'accuracy'
              )

# %%
steps_per_epoch = 60000//BATCH_SIZE 
history = more_layers_model.fit(set_entrenamiento, steps_per_epoch=steps_per_epoch, epochs=EPOCHS,
          validation_data=set_validacion, validation_steps=1)
# Out:
# Epoch 1/10
# 468/468 [==============================] - 2s 4ms/step - loss: 0.5537 - accuracy: 0.8438 - val_loss: 0.1467 - val_accuracy: 0.9540
# Epoch 2/10
# 468/468 [==============================] - 2s 4ms/step - loss: 0.1303 - accuracy: 0.9614 - val_loss: 0.1033 - val_accuracy: 0.9664
# Epoch 3/10
# 468/468 [==============================] - 2s 4ms/step - loss: 0.0846 - accuracy: 0.9737 - val_loss: 0.0845 - val_accuracy: 0.9739
# Epoch 4/10
# 468/468 [==============================] - 2s 4ms/step - loss: 0.0592 - accuracy: 0.9832 - val_loss: 0.0776 - val_accuracy: 0.9755
# Epoch 5/10
# 468/468 [==============================] - 2s 4ms/step - loss: 0.0466 - accuracy: 0.9862 - val_loss: 0.0767 - val_accuracy: 0.9752
# Epoch 6/10
# 468/468 [==============================] - 2s 4ms/step - loss: 0.0359 - accuracy: 0.9890 - val_loss: 0.0789 - val_accuracy: 0.9766
# Epoch 7/10
# 468/468 [==============================] - 2s 4ms/step - loss: 0.0291 - accuracy: 0.9911 - val_loss: 0.0865 - val_accuracy: 0.9743
# Epoch 8/10
# 468/468 [==============================] - 2s 4ms/step - loss: 0.0245 - accuracy: 0.9930 - val_loss: 0.0756 - val_accuracy: 0.9784
# Epoch 9/10
# 468/468 [==============================] - 2s 4ms/step - loss: 0.0169 - accuracy: 0.9951 - val_loss: 0.0773 - val_accuracy: 0.9789
# Epoch 10/10
# 468/468 [==============================] - 2s 3ms/step - loss: 0.0160 - accuracy: 0.9949 - val_loss: 0.0826 - val_accuracy: 0.9771

# %%
plt.plot(range(EPOCHS), history.history['accuracy'], label='Accuracy')
plt.plot(range(EPOCHS), history.history['val_accuracy'], label='Validation Accuracy')
plt.fill_between(range(EPOCHS),
                 history.history['accuracy'],
                 history.history['val_accuracy'],
                 color='salmon',
                 alpha = 0.3)
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# # Cambiando el Learning Rate Decay

# %%
import math

def lr_decay (epoch):
  return 0.01 * math.pow (0.6, epoch)

def plot_learning_rate(lr_func, epochs):
  xx = np.arange(epochs+1, dtype=np.float)
  y = [lr_decay(x) for x in xx]
  fig, ax = plt.subplots(figsize=(9, 6))
  ax.set_xlabel('epochs')
  ax.set_title('Learning rate\ndecays from {:0.3g} to {:0.3g}'.format(y[0], y[-2]))
  ax.minorticks_on()
  ax.grid(True, which='major', axis='both', linestyle='-', linewidth=1)
  ax.grid(True, which='minor', axis='both', linestyle=':', linewidth=0.5)
  ax.step(xx,y, linewidth=3, where='post')
  display.display(fig)

lr_decay_callback = tf.keras.callbacks.LearningRateScheduler (lr_decay, verbose=True)

plot_learning_rate (lr_decay, EPOCHS)

# %%
more_layers_model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.01),
              loss= 'categorical_crossentropy',
              metrics = 'accuracy'
              )

# %%
steps_per_epoch = 60000//BATCH_SIZE 
history = more_layers_model.fit(set_entrenamiento, steps_per_epoch=steps_per_epoch, epochs=EPOCHS,
          validation_data=set_validacion, validation_steps=1, callbacks=[lr_decay_callback])
# Out:
# Epoch 1/10
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.01.
# 468/468 [==============================] - 2s 4ms/step - loss: 0.1684 - accuracy: 0.9537 - val_loss: 0.1259 - val_accuracy: 0.9639
# Epoch 2/10
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.006.
# 468/468 [==============================] - 2s 3ms/step - loss: 0.0764 - accuracy: 0.9772 - val_loss: 0.0939 - val_accuracy: 0.9735
# Epoch 3/10
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0036.
# 468/468 [==============================] - 2s 4ms/step - loss: 0.0418 - accuracy: 0.9875 - val_loss: 0.0875 - val_accuracy: 0.9778
# Epoch 4/10
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0021599999999999996.
# 468/468 [==============================] - 2s 4ms/step - loss: 0.0215 - accuracy: 0.9930 - val_loss: 0.0694 - val_accuracy: 0.9808
# Epoch 5/10
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001296.
# 468/468 [==============================] - 2s 4ms/step - loss: 0.0122 - accuracy: 0.9963 - val_loss: 0.0678 - val_accuracy: 0.9841
# Epoch 6/10
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0007775999999999998.
# 468/468 [==============================] - 2s 4ms/step - loss: 0.0062 - accuracy: 0.9986 - val_loss: 0.0697 - val_accuracy: 0.9838
# Epoch 7/10
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0004665599999999999.
# 468/468 [==============================] - 2s 4ms/step - loss: 0.0040 - accuracy: 0.9993 - val_loss: 0.0703 - val_accuracy: 0.9834
# Epoch 8/10
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.00027993599999999994.
# 468/468 [==============================] - 2s 4ms/step - loss: 0.0029 - accuracy: 0.9997 - val_loss: 0.0706 - val_accuracy: 0.9837
# Epoch 9/10
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.00016796159999999993.
# 468/468 [==============================] - 2s 4ms/step - loss: 0.0027 - accuracy: 0.9996 - val_loss: 0.0708 - val_accuracy: 0.9837
# Epoch 10/10
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.00010077695999999997.
# 468/468 [==============================] - 2s 4ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 0.0713 - val_accuracy: 0.9836

# %%
plt.plot(range(EPOCHS), history.history['accuracy'], label='Accuracy')
plt.plot(range(EPOCHS), history.history['val_accuracy'], label='Validation Accuracy')
plt.fill_between(range(EPOCHS),
                 history.history['accuracy'],
                 history.history['val_accuracy'],
                 color='salmon',
                 alpha = 0.3)
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend()
plt.show()

# %%
model_drop = tf.keras.Sequential(
  [
      tf.keras.layers.Input(shape=(28*28,)),
      tf.keras.layers.Dense(200, activation='relu'),
      tf.keras.layers.Dropout(0.25),
      tf.keras.layers.Dense(100, activation='relu'),
      tf.keras.layers.Dropout(0.25),
      tf.keras.layers.Dense(60, activation='relu'),
      tf.keras.layers.Dropout(0.25),
      tf.keras.layers.Dense(10, activation='softmax')
  ])

model_drop.compile(optimizer=tf.keras.optimizers.Adam(lr=0.01),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model_drop.summary ()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 200)               157000
# _________________________________________________________________
# dropout (Dropout)            (None, 200)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 100)               20100
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 60)                6060
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 60)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 10)                610
# =================================================================
# Total params: 183,770
# Trainable params: 183,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
steps_per_epoch = 60000//BATCH_SIZE 
history = model_drop.fit(set_entrenamiento, steps_per_epoch=steps_per_epoch, epochs=EPOCHS,
          validation_data=set_validacion, validation_steps=1, callbacks=[lr_decay_callback])
# Out:
# Epoch 1/10
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.01.
# 468/468 [==============================] - 2s 4ms/step - loss: 0.6342 - accuracy: 0.7996 - val_loss: 0.1765 - val_accuracy: 0.9499
# Epoch 2/10
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.006.
# 468/468 [==============================] - 2s 4ms/step - loss: 0.2287 - accuracy: 0.9400 - val_loss: 0.1392 - val_accuracy: 0.9629
# Epoch 3/10
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0036.
# 468/468 [==============================] - 2s 4ms/step - loss: 0.1775 - accuracy: 0.9528 - val_loss: 0.1111 - val_accuracy: 0.9680
# Epoch 4/10
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0021599999999999996.
# 468/468 [==============================] - 2s 4ms/step - loss: 0.1377 - accuracy: 0.9620 - val_loss: 0.1038 - val_accuracy: 0.9722
# Epoch 5/10
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001296.
# 468/468 [==============================] - 2s 4ms/step - loss: 0.1157 - accuracy: 0.9680 - val_loss: 0.0955 - val_accuracy: 0.9741
# Epoch 6/10
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0007775999999999998.
# 468/468 [==============================] - 2s 4ms/step - loss: 0.1021 - accuracy: 0.9716 - val_loss: 0.0916 - val_accuracy: 0.9755
# Epoch 7/10
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0004665599999999999.
# 468/468 [==============================] - 2s 4ms/step - loss: 0.0942 - accuracy: 0.9729 - val_loss: 0.0913 - val_accuracy: 0.9754
# Epoch 8/10
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.00027993599999999994.
# 468/468 [==============================] - 2s 4ms/step - loss: 0.0886 - accuracy: 0.9752 - val_loss: 0.0875 - val_accuracy: 0.9769
# Epoch 9/10
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.00016796159999999993.
# 468/468 [==============================] - 2s 4ms/step - loss: 0.0860 - accuracy: 0.9756 - val_loss: 0.0862 - val_accuracy: 0.9763
# Epoch 10/10
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.00010077695999999997.
# 468/468 [==============================] - 2s 4ms/step - loss: 0.0809 - accuracy: 0.9767 - val_loss: 0.0865 - val_accuracy: 0.9767

# %%
plt.plot(range(EPOCHS), history.history['accuracy'], label='Accuracy')
plt.plot(range(EPOCHS), history.history['val_accuracy'], label='Validation Accuracy')
plt.fill_between(range(EPOCHS),
                 history.history['accuracy'],
                 history.history['val_accuracy'],
                 color='salmon',
                 alpha = 0.3)
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend()
plt.show()

# %%
probabilities = adam_model.predict(font_digits, steps=1)
predicted_labels = np.argmax(probabilities, axis=1)
display_digits(font_digits, predicted_labels, font_labels, "predictions from local fonts (bad predictions in red)", 20)
